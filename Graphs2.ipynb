# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
##stats

from scipy import stats
## plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
dataset1
# Out:
# array([-0.28458004, -1.10827714,  0.111646  ,  0.37236905,  1.41884472,
#        -0.99049925, -0.16800052, -0.50962761,  1.34431726, -1.06420883,
#        -1.98808378,  0.53433588, -0.81832465,  1.40546588,  0.75105706,
#         0.82924645,  0.27531942, -0.41058564,  1.60754079, -0.59420738,
#        -1.10449601,  1.05950115, -0.64411845,  0.13089026,  1.37113704,
#         1.89132387,  1.6035311 ,  0.15369708,  0.54921573, -0.47219526,
#        -1.29558596, -1.84618036, -0.06480056, -0.45874371, -0.23615916,
#        -0.98622057,  0.07775461,  0.16081325,  0.76157529,  0.89653059,
#         1.52217403,  1.26119348, -0.72938386, -3.16405322, -0.65833851,
#        -1.35119542,  0.37623015,  0.77625147,  0.48735794,  0.16474081,
#        -0.40038976,  1.32954662,  0.01307812, -0.1907971 ,  1.71508311,
#        -1.06292378,  0.5894111 ,  0.26908217,  0.07124392, -0.97134194,
#         0.09465881, -0.31389399,  0.26479803, -0.83176891,  0.70157252,
# ...

# %%
plt.hist(dataset1);;;;;;;;;;;;;;;;;;
# Out:
# (array([ 1.,  1.,  2.,  3., 21., 20., 18., 17.,  9.,  8.]),
#  array([-3.16405322, -2.65851551, -2.1529778 , -1.64744009, -1.14190238,
#         -0.63636467, -0.13082696,  0.37471075,  0.88024845,  1.38578616,
#          1.89132387]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1 , histtype = 'bar', edgecolor = 'black') ### bargraph
# Out:
# (array([ 1.,  1.,  2.,  3., 21., 20., 18., 17.,  9.,  8.]),
#  array([-3.16405322, -2.65851551, -2.1529778 , -1.64744009, -1.14190238,
#         -0.63636467, -0.13082696,  0.37471075,  0.88024845,  1.38578616,
#          1.89132387]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([ 4.,  7.,  5., 14., 13., 14., 13.,  3.,  3.,  4.]),
#  array([-1.99265701, -1.53081727, -1.06897754, -0.6071378 , -0.14529806,
#          0.31654167,  0.77838141,  1.24022114,  1.70206088,  2.16390061,
#          2.62574035]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1, density = True, color = 'indianred', alpha = 0.5, bins=20)
plt.hist(dataset2, density = True, color = 'blue', alpha = 0.5, bins = 20)  ## bins interval x-axis total bar between -2 to 2
# Out:
# (array([0.162394  , 0.05413133, 0.21652533, 0.162394  , 0.10826266,
#         0.162394  , 0.27065666, 0.48718199, 0.27065666, 0.43305065,
#         0.32478799, 0.43305065, 0.48718199, 0.21652533, 0.10826266,
#         0.05413133, 0.        , 0.162394  , 0.05413133, 0.162394  ]),
#  array([-1.99265701, -1.76173714, -1.53081727, -1.2998974 , -1.06897754,
#         -0.83805767, -0.6071378 , -0.37621793, -0.14529806,  0.0856218 ,
#          0.31654167,  0.54746154,  0.77838141,  1.00930127,  1.24022114,
#          1.47114101,  1.70206088,  1.93298075,  2.16390061,  2.39482048,
#          2.62574035]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)

# %%
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)
# Out:
# D:\stdy\datasc\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data1, data2, kind='hex')
# Out:
# D:\stdy\datasc\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
