# %%
import pandas as pd
import numpy as np
from pandas import Series , DataFrame
from pandas_datareader import data
import datetime

# %%
# 1 jan 2010 - 1 jan 2013
# 1 jan 2015 - 1 jan 2018

adj = data.get_data_yahoo(['TATAMOTORS.BO', 'M&M.NS'], start = datetime.datetime(2010,1,1), end = datetime.datetime(2013,1,1))['Adj Close']

# %%
adj
# Out:
# Symbols     TATAMOTORS.BO      M&M.NS
# Date
# 2010-01-04     153.321976  262.277863
# 2010-01-05     150.273697  267.106293
# 2010-01-06     150.486786  273.513214
# 2010-01-07     145.418671  268.301819
# 2010-01-08     146.234039  268.325012
# ...                   ...         ...
# 2012-12-26     298.722748  447.369568
# 2012-12-27     302.733124  440.597290
# 2012-12-28     302.879822  437.874207
# 2012-12-31     305.569702  441.213043
# 2013-01-01     309.482239  446.019836
#
# [742 rows x 2 columns]

# %%
adj1 = data.get_data_yahoo(['TATAMOTORS.BO','M&M.NS'], start = datetime.datetime(2015,1,1), end = datetime.datetime(2018,1,1))['Adj Close']

# %%
adj1
# Out:
# Symbols     TATAMOTORS.BO      M&M.NS
# Date
# 2015-01-01     492.775116  586.413025
# 2015-01-02     506.077332  580.534973
# 2015-01-05     518.341064  577.595886
# 2015-01-06     495.593781  574.372437
# 2015-01-07     488.571838  580.298035
# ...                   ...         ...
# 2017-12-26     423.600006  722.359314
# 2017-12-27     422.500000  727.424744
# 2017-12-28     418.399994  730.541992
# 2017-12-29     431.200012  731.662231
# 2018-01-01     425.399994  725.379150
#
# [741 rows x 2 columns]

# %%
adj.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adj1.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
type(adj)
# Out:
# pandas.core.frame.DataFrame

# %%
#pd.merge(adj, adj1, left_index=True, right_index=True)

a = pd.concat([adj,adj1],axis=1)

# %%
adj.columns
# Out:
# Index(['TATAMOTORS.BO', 'M&M.NS'], dtype='object', name='Symbols')

# %%
a.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adj.corr()
# Out:
# Symbols        TATAMOTORS.BO    M&M.NS
# Symbols
# TATAMOTORS.BO       1.000000  0.629013
# M&M.NS              0.629013  1.000000

# %%
adj1.corr()
# Out:
# Symbols        TATAMOTORS.BO    M&M.NS
# Symbols
# TATAMOTORS.BO       1.000000  0.132936
# M&M.NS              0.132936  1.000000

# %%
b=a.corr()
b
# Out:
# Symbols        TATAMOTORS.BO    M&M.NS  TATAMOTORS.BO    M&M.NS
# Symbols
# TATAMOTORS.BO       1.000000  0.629013            NaN       NaN
# M&M.NS              0.629013  1.000000            NaN       NaN
# TATAMOTORS.BO            NaN       NaN       1.000000  0.132936
# M&M.NS                   NaN       NaN       0.132936  1.000000

# %%
b.plot()
# Out:
# <AxesSubplot:xlabel='Symbols'>

# %%
c = b.pct_change()   ## pct change always used on volume total growth of the company

# %%
c.plot()
# Out:
# <AxesSubplot:xlabel='Symbols'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab2bf477c361> in <module>
# ----> 1 randn(90)
#
# NameError: name 'randn' is not defined
